# %%
from searchAPI import googleSearcher

# %%
searcher = googleSearcher()

# %%
searcher.searchKeyword('chelsea vs nottingham','fbref.com')
# Out:
# [{'kind': 'customsearch#result',
#   'title': 'Chelsea vs. Nottingham Forest Match Report – Saturday September ...',
#   'htmlTitle': '<b>Chelsea vs</b>. <b>Nottingham</b> Forest Match Report – Saturday September ...',
#   'link': 'https://fbref.com/en/matches/44e89d37/Chelsea-Nottingham-Forest-September-2-2023-Premier-League',
#   'displayLink': 'fbref.com',
#   'snippet': 'Sep 2, 2023 ... Check out the match summary, team stats, player stats, goals scored and more for the football match between Chelsea and Nottingham Forest on\xa0...',
#   'htmlSnippet': 'Sep 2, 2023 <b>...</b> Check out the match summary, team stats, player stats, goals scored and more for the football match between <b>Chelsea</b> and <b>Nottingham</b> Forest on&nbsp;...',
#   'cacheId': '43hwSYNpbMEJ',
#   'formattedUrl': 'https://fbref.com/.../Chelsea-Nottingham-Forest-September-2-2023-Premier- League',
# ...
