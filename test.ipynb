# %%
from searchAPI import googleSearcher
import requests
import json
from bs4 import BeautifulSoup

# %%
searcher = googleSearcher()

# %%
sample = searcher.searchKeyword('conor gallagher','fbref.com')[0]

# %%
sample['link']
# Out:
# 'https://fbref.com/en/players/c2731c10/Conor-Gallagher'

# %%
res = requests.get(sample['link'])
dom = BeautifulSoup(res.content)

# %%
dom.body.div
# Out:
# <div id="wrap">
# <div id="translations" role="navigation">
# <div class="links">
# <div class="welcome">Welcome, football fans from around the world!</div>
# <div><span class="use">Use FBref in: </span>
# <div class="langs">
# <a class="pt" href="https://fbref.com/pt/players/c2731c10/Conor-Gallagher" onclick="sr_set_trans_choice('pt');">Português</a>
#          ·                        <a class="en" href="https://fbref.com/en/players/c2731c10/Conor-Gallagher" onclick="sr_set_trans_choice('en');">English</a>
#          ·                        <a class="fr" href="https://fbref.com/fr/players/c2731c10/Conor-Gallagher" onclick="sr_set_trans_choice('fr');">Français</a>
#          ·                        <a class="it" href="https://fbref.com/it/players/c2731c10/Conor-Gallagher" onclick="sr_set_trans_choice('it');">Italiano</a>
#          ·                        <a class="de" href="https://fbref.com/de/players/c2731c10/Conor-Gallagher" onclick="sr_set_trans_choice('de');">Deutsch</a>
# ...
